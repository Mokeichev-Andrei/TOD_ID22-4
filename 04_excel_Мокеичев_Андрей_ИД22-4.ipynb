# %% [markdown]
# # Работа с Excel

# %% [markdown]
# ## Лабораторная работа 7.1

# %%
import pandas as pd
import xlwings as xw
import csv
import numpy as np

# %% [markdown]
# 1. Загрузите данные из файлов `reviews_sample.csv` (__ЛР2__) и `recipes_sample.csv` (__ЛР5__) в виде `pd.DataFrame`. Обратите внимание на корректное считывание столбца(ов) с индексами. Оставьте в таблице с рецептами следующие столбцы: `id`, `name`, `minutes`, `submitted`, `description`, `n_ingredients`

# %%
reviews = pd.read_csv('reviews_sample.csv')
recipes = pd.read_csv('recipes_sample.csv')[['id', 'name', 'minutes', 'submitted', 'description', 'n_ingredients']]

reviews
# Out:
#         Unnamed: 0     user_id  recipe_id        date  rating  \
# 0           370476       21752      57993  2003-05-01       5
# 1           624300      431813     142201  2007-09-16       5
# 2           187037      400708     252013  2008-01-10       4
# 3           706134  2001852463     404716  2017-12-11       5
# 4           312179       95810     129396  2008-03-14       5
# ...            ...         ...        ...         ...     ...
# 126691     1013457     1270706     335534  2009-05-17       4
# 126692      158736     2282344       8701  2012-06-03       0
# 126693     1059834      689540     222001  2008-04-08       5
# 126694      453285  2000242659     354979  2015-06-02       5
# 126695      691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# 3       These are a favorite for the holidays and so e...
# 4       Excellent soup!  The tomato flavor is just gre...
# ...                                                   ...
# 126691  This recipe was great! I made it last night. I...
# 126692  This recipe is outstanding. I followed the rec...
# 126693  Well, we were not a crowd but it was a fabulou...
# 126694  I have been a steak eater and dedicated BBQ gr...
# 126695  Wonderful and simple to prepare seasoning blen...
#
# [126696 rows x 6 columns]

# %% [markdown]
# 2. Случайным образом выберите 5% строк из каждой таблицы и сохраните две таблицы на разные листы в один файл `recipes.xlsx`. Дайте листам названия "Рецепты" и "Отзывы", соответствующие содержанию таблиц.

# %%
s1 = reviews.sample(int(reviews.shape[0] * 0.05))
s1
# Out:
#         Unnamed: 0     user_id  recipe_id        date  rating  \
# 34         1064295      311625      90485  2008-10-27       5
# 122313      930505     1213941      34667  2009-08-19       5
# 100643      444950      175124      66459  2006-10-29       5
# 17227       609018      237123      97196  2006-10-05       5
# 12862       462678       47723     142524  2009-03-20       5
# ...            ...         ...        ...         ...     ...
# 42035      1059949  2000445724     132469  2015-09-01       4
# 93371       880351     1771441     206929  2010-12-27       0
# 81451       114896  2001267243     186887  2016-11-24       5
# 42635       774077      879027     128956  2008-07-08       5
# 120841      909431      157425     369844  2012-09-02       5
#
#                                                    review
# 34      This was really good, though I made a few modi...
# 122313  Loved this marinade! It was easy and quick to ...
# 100643  Someone just asked me for a cake recipe that u...
# 17227   Yumm, this turned out great.  I love that ther...
# 12862   I prepared exactly according to instructions, ...
# ...                                                   ...
# 42035   Loved it ! Very good I am thinking I will &amp...
# 93371   These were amazing!  I left out the nuts, adde...
# 81451   Stop looking, this is the recipe you want This...
# 42635   This was Great. I used garlic powder because I...
# 120841  I dont care for fussy salads with so many topp...
#
# [6334 rows x 6 columns]

# %%
s2 = recipes.sample(int(recipes.shape[0] * 0.05))
s2
# Out:
#            id                                               name  minutes  \
# 18064  496257  montana wild rice beef stew   with five ingred...      495
# 29690  406964        yogurt fluff   only 1 weight watchers point       35
# 18183   48851                 move over applesauce fruit compote       25
# 17137  204319                        mary s mississippi mud cake       55
# 20853  394598                    pineapple upside down cornbread       95
# ...       ...                                                ...      ...
# 12329  183545                  graham and peanut butter bon bons       85
# 18744   34231        no way it s fat free sugar free mango kulfi      245
# 16901   82451                          manicotti  beef or turkey       60
# 28130   92990                             tuna unusual casserole       40
# 17089   76633                         marsha s whole wheat pizza       65
#
#         submitted                                        description  \
# 18064  2013-02-27  this recipe is from gooseberry patch's book "s...
# 29690  2010-01-05  this is a real treat if you are counting point...
# 18183  2002-12-15  this is good with desserts, but we like it wit...
# 17137  2007-01-08  this cake is so darn good ... mary made it for...
# 20853  2009-10-13  i love pineapple upside down cake and i love c...
# ...           ...                                                ...
# 12329  2006-08-28  this comes from the back of the keebler graham...
# 18744  2002-07-15  i made this recipe up after searching the inte...
# 16901  2004-01-29  this is an adopted recipe that i chose because...
# 28130  2004-06-09  this is a recipe i have had for 30+ years. ori...
# 17089  2003-11-16  my friend marsha has made pizza every friday n...
#
#        n_ingredients
# 18064            5.0
# 29690            6.0
# 18183            6.0
# 17137            NaN
# 20853            NaN
# ...              ...
# 12329            5.0
# 18744            5.0
# 16901           10.0
# 28130            NaN
# 17089            5.0
#
# [1500 rows x 6 columns]

# %%
with pd.ExcelWriter('recipes.xlsx') as writer:
    s1.to_excel(writer, 'Отзывы')
    s2.to_excel(writer, 'Рецепты')

# %% [markdown]
# 3. Используя `xlwings`, добавьте на лист `Рецепты` столбец `seconds_assign`, показывающий время выполнения рецепта в секундах. Выполните задание при помощи присваивания массива значений диапазону ячеек.

# %%
wb = xw.Book('recipes.xlsx')
sht = wb.sheets['Рецепты']
sht.range('H1').value = 'seconds_assign'
sht.range('H2').options(transpose = True).value = [i * 60 for i in s2['minutes']]

# %% [markdown]
# 4. Используя `xlwings`, добавьте на лист `Рецепты` столбец `seconds_formula`, показывающий время выполнения рецепта в секундах. Выполните задание при помощи формул Excel.

# %%
sht.range('I1').value = 'seconds_formula'
fml = sht.range('I2').formula = '=D2*60'
sht.range('I2:I1501').formula = fml

# %% [markdown]
# 5. Сделайте названия всех добавленных столбцов полужирными и выровняйте по центру ячейки.

# %%
import openpyxl.styles
recipes_sh = wb.sheets['Рецепты']
recipes_sh.range('H1:I1').api.Font.Bold = True
recipes_sh.range('H1:I1').api.HorizontalAlignment = xw.constants.HAlign.xlHAlignCenter

# %% [markdown]
# 6. Раскрасьте ячейки столбца `minutes` в соответствии со следующим правилом: если рецепт выполняется быстрее 5 минут, то цвет - зеленый; от 5 до 10 минут - жёлтый; и больше 10 - красный.

# %%
for i in range(2, 1502):
    if sht.range(f'D{i}').value < 5:
        sht.range(f'D{i}').color = (0, 128, 0)
    elif 5 <= sht.range(f'D{i}').value <= 10:
        sht.range(f'D{i}').color = (255, 255, 0)
    else:
        sht.range(f'D{i}').color = (255, 0, 0)

# %% [markdown]
# 7. Добавьте на лист `Рецепты`  столбец `n_reviews`, содержащий кол-во отзывов для этого рецепта. Выполните задание при помощи формул Excel.

# %%
sht.range('J1').value = 'n_reviews'
fml = sht.range('J2').formula = '=COUNTIF(Отзывы!D1:D6335, B2)'
sht.range('J2:J1501').formula = fml

# %% [markdown]
# ## Лабораторная работа 7.2

# %% [markdown]
# 8. Напишите функцию `validate()`, которая проверяет соответствие всех строк из листа `Отзывы` следующим правилам:
#     * Рейтинг - это число от 0 до 5 включительно
#     * Соответствующий рецепт имеется на листе `Рецепты`
#
# В случае несоответствия этим правилам, выделите строку красным цветом

# %%
def validate():
    wb = xw.Book('recipes.xlsx')
    sht = wb.sheets['Отзывы']
    for i in range(2, 6336):
        if sht.range(f'F{i}').value < 0 or sht.range(f'F{i}').value > 5 or sht.range(f'D{i}').value not in wb.sheets['Рецепты'].range('B2:B1501').value:
            sht.range(f'A{i}:Z{i}').color = (255, 0, 0)
validate()

# %% [markdown]
# 9. В файле `recipes_model.csv` находится модель данных предметной области "рецепты". При помощи пакета `csv` считайте эти данные. При помощи пакета `xlwings` запишите данные на лист `Модель` книги `recipes_model.xlsx`, начиная с ячейки `A2`, не используя циклы. Сделайте скриншот текущего состояния листа и прикрепите в ячейку ноутбука.

# %%
import csv
with open('recipes_model.csv','r') as f:
    rec_mod = csv.reader(f, delimiter = '\t')
    rec_data = list(rec_mod)
model = xw.Book()
model_sheet = model.sheets.add('Модель')
model_sheet.range('A2').value = rec_data
model.save('recipes_model1.xlsx')
model.close()

# %% [markdown]
# 10. При помощи пакета `xlwings` добавьте в столбец J формулу для описания столбца на языке SQL. Формула должна реализовывать следующую логику:
#
#     1\. в начале строки идут значения из столбцов В и C (значение столбца С приведено к верхнему регистру), разделенные пробелом
#
#     2\. далее идут слова на основе столбца "Ключ"
#         2.1 если в столбце "Ключ" указано значение "PK", то дальше через пробел идет ключевое слово "PRIMARY KEY"
#         2.2 если в столбце "Ключ" указано значение "FK", то дальше через пробел идет ключевое слово "REFERENCES", затем значения столбцов H и I в формате "название_таблицы(название_столбца)"
#
#     3\. если в столбце "Обязательно к заполнению" указано значение "Y" и в столбце "Ключ" указано не "PK", то дальше через пробел идет ключевое слово "NOT NULL".
#
# Заполните этой формулой необходимое количество строк, используя "протягивание". Количество строк для протягивания определите на основе данных.
#
# Сделайте скриншот текущего состояния листа и прикрепите в ячейку ноутбука.

# %%
wb = xw.Book('recipes_model1.xlsx')
sheet = wb.sheets['Модель']

# Определяем количество строк, начиная со второй строки
n_rows = sheet.range('A2').current_region.last_cell.row - 1

# Протягиваем формулу по столбцу J
for i in range(2, n_rows+2):
    # Получаем значения из столбцов B, C, H и I
    b_val = sheet.range(f'B{i}').value
    c_val = sheet.range(f'C{i}').value.upper()
    h_val = sheet.range(f'H{i}').value
    i_val = sheet.range(f'I{i}').value
    
    # Формируем строку на основе столбцов B, C и Ключ
    j_val = f'{b_val} {c_val}'
    key_val = sheet.range(f'F{i}').value
    if key_val == 'PK':
        j_val += ' PRIMARY KEY'
    elif key_val == 'FK':
        j_val += f' REFERENCES {h_val}({i_val})'
        
    # Добавляем ключевое слово "NOT NULL", если столбец обязателен к заполнению
    required_val = sheet.range(f'D{i}').value
    if required_val == 'Y' and key_val != 'PK':
        j_val += ' NOT NULL'
    
    # Записываем полученное значение в столбец J
    sheet.range(f'J{i}').value = j_val
    
wb.save('recipes_model.xlsx')
wb.close()

# %% [markdown]
# 11. При помощи пакета `xlwings` измените стилизацию листа `Модель`.
# * для заголовков добавьте заливку цвета `00ccff`
# * примените автоподбор ширины столбца;
# * сделайте шрифт заголовков полужирным;
# * добавьте таблице автофильтр.
#
# Сделайте скриншот текущего состояния листа и прикрепите в ячейку ноутбука.

# %%
wb = xw.Book('recipes_model1.xlsx')
sht = wb.sheets['Модель']
sht.range('A2:J2').color = (0, 204, 255) 
sht.autofit('c')
sht.range('A2:J2').api.Font.Bold = True
sht.range('A2:J2').api.AutoFilter()
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Cell In[26], line 6
#       4 sht.autofit('c')
#       5 sht.range('A2:J2').api.Font.Bold = True
# ----> 6 sht.range('A2:J2').api.AutoFilter()
#
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:109, in COMRetryMethodWrapper.__call__(self, *args, **kwargs)
#     107 while True:
#     108     try:
# --> 109         v = self.__method(*args, **kwargs)
#     110         if isinstance(v, (CDispatch, CoClassBaseClass, DispatchBaseClass)):
#     111             return COMRetryObjectWrapper(v)
#
# File ~\anaconda3\lib\site-packages\win32com\gen_py\00020813-0000-0000-C000-000000000046x0x1x9.py:32400, in Range.AutoFilter(self, Field, Criteria1, Operator, Criteria2, VisibleDropDown)
#   32398 def AutoFilter(self, Field=defaultNamedNotOptArg, Criteria1=defaultNamedNotOptArg, Operator=1, Criteria2=defaultNamedOptArg
#   32399 		, VisibleDropDown=defaultNamedOptArg):
# > 32400 	return self._ApplyTypes_(793, 1, (12, 0), ((12, 17), (12, 17), (3, 49), (12, 17), (12, 17)), 'AutoFilter', None,Field
#   32401 		, Criteria1, Operator, Criteria2, VisibleDropDown)
#
# File ~\anaconda3\lib\site-packages\win32com\client\__init__.py:572, in DispatchBaseClass._ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args)
#     570 def _ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args):
#     571     return self._get_good_object_(
# --> 572         self._oleobj_.InvokeTypes(dispid, 0, wFlags, retType, argTypes, *args),
#     573         user,
#     574         resultCLSID,
#     575     )
#
# com_error: (-2147352567, 'Ошибка.', (0, 'Microsoft Excel', 'Метод AutoFilter из класса Range завершен неверно', 'xlmain11.chm', 0, -2146827284), None)

# %% [markdown]
# 12. Посчитайте количество атрибутов для каждой из сущностей. Создайте лист `Статистика` и запишите в него результат группировки, начиная с ячейки "А1". Визуализируйте полученный результат при помощи столбчатой диаграммы. Сохраните полученную визуализацию на лист `Статистика`, начиная с ячейки "E2".  Сделайте скриншот листа `Статистика` и прикрепите в ячейку ноутбука.
#
# * Вы можете воспользоваться методами для визуализации, которые поставляются вместе с объектами `pandas` (см. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot)

# %%
wb.sheets.add('Cтатистика')
sht = wb.sheets['Статистика']
model = sht['A1:B18'].value
m_t = pd.DataFrame(model[1:], columns = model [0])
gr = m_t.groupby('Сущность').count()
sht['A1'].value = gr
figure = gr.plot.bar().get_figure()
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 wb.sheets.add('Cтатистика')
# ----> 2 sht = wb.sheets['Статистика']
#       3 model = sht['A1:B18'].value
#       4 m_t = pd.DataFrame(model[1:], columns = model [0])
#
# File ~\anaconda3\lib\site-packages\xlwings\main.py:88, in Collection.__getitem__(self, key)
#      84     raise ValueError(
#      85         self.impl.__class__.__name__ + " object does not support slicing"
#      86     )
#      87 else:
# ---> 88     return self(key)
#
# File ~\anaconda3\lib\site-packages\xlwings\main.py:5070, in Sheets.__call__(self, name_or_index)
#    5068     return name_or_index
#    5069 else:
# -> 5070     return Sheet(impl=self.impl(name_or_index))
#
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:895, in Sheets.__call__(self, name_or_index)
#     894 def __call__(self, name_or_index):
# --> 895     return Sheet(xl=self.xl(name_or_index))
#
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:223, in COMRetryObjectWrapper.__call__(self, *args, **kwargs)
#     221 for i in range(N_COM_ATTEMPTS + 1):
#     222     try:
# --> 223         v = self._inner(*args, **kwargs)
#     224         if isinstance(v, (CDispatch, CoClassBaseClass, DispatchBaseClass)):
#     225             return COMRetryObjectWrapper(v)
#
# File ~\anaconda3\lib\site-packages\win32com\gen_py\00020813-0000-0000-C000-000000000046x0x1x9.py:35340, in Sheets.__call__(self, Index)
#   35339 def __call__(self, Index=defaultNamedNotOptArg):
# > 35340 	ret = self._oleobj_.InvokeTypes(0, LCID, 2, (9, 0), ((12, 1),),Index
#   35341 		)
#   35342 	if ret is not None:
#   35343 		ret = Dispatch(ret, '__call__', None)
#
# com_error: (-2147352567, 'Ошибка.', (0, None, None, None, 0, -2147352565), None)
